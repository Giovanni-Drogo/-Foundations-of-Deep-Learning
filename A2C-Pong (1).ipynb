# %%
#导入必要的库
import gymnasium as gym
import ale_py
from stable_baselines3 import A2C
from stable_baselines3.common.env_util import make_vec_env
# Out:
# 2025-05-16 22:26:51.213713: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-16 22:26:51.254314: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-16 22:26:52.042421: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
gym.register_envs(ale_py)
vec_env = make_vec_env("ALE/Pong-v5", n_envs=4, env_kwargs={"max_episode_steps": 1000})


model = A2C("MlpPolicy", vec_env, verbose=1)

model.learn(total_timesteps=500_000, log_interval=3)
model.save("a2c_pong")
# Out:
# A.L.E: Arcade Learning Environment (version 0.11.0+dfae0bd)
# [Powered by Stella]
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# /usr/local/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run A2C on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ------------------------------------
# | time/                 |          |
# |    fps                | 68       |
# |    iterations         | 3        |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 60       |
# | train/                |          |
# ...

# %%
#导入必要的库
import gymnasium as gym
import ale_py
from stable_baselines3 import A2C
from stable_baselines3.common.env_util import make_vec_env
# Out:
# 2025-05-16 22:45:36.001142: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-16 22:45:36.041623: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-16 22:45:36.838646: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import gymnasium as gym
from stable_baselines3 import A2C

# 创建环境（无需手动注册，但需确保已安装 ale-py）
env = gym.make("ALE/Pong-v5", render_mode="human")

# 加载模型时必须添加 .zip 后缀
model = A2C.load("/mnt/workspace/强化学习-2/a2c/a2c_pong.zip")  # ✅ 确保模型文件路径正确
num_episodes = 10
total_rewards = []


for _ in range(num_episodes):
    obs, info = env.reset()
    episode_reward = 0
    while True:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, _ = env.step(int(action))
        episode_reward += reward
        if terminated or truncated:
            break
    total_rewards.append(episode_reward)
    print(f"Episode Reward: {episode_reward}")

print(f"Average Reward: {sum(total_rewards)/num_episodes}")
# Out:
# A.L.E: Arcade Learning Environment (version 0.11.0+dfae0bd)
# [Powered by Stella]
# /usr/local/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run A2C on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# Episode Reward: -21.0
# Episode Reward: -21.0
# Episode Reward: -21.0
# Episode Reward: -21.0
# Episode Reward: -21.0
# Episode Reward: -21.0
# Episode Reward: -21.0
# Episode Reward: -21.0
# Episode Reward: -21.0
# Episode Reward: -21.0
# Average Reward: -21.0

# %%
import gymnasium as gym
from stable_baselines3 import A2C

# 创建环境（无需手动注册，但需确保已安装 ale-py）
env = gym.make("ALE/Pong-v5", render_mode="human")

# 加载模型时必须添加 .zip 后缀
model = A2C.load("/mnt/workspace/强化学习-2/a2c/a2c_pong.zip")  # ✅ 确保模型文件路径正确

obs, info = env.reset()  # 重置环境
total_reward = 0  # 总奖励

# 迭代1000次
for _ in range(1000):
    # 确定性策略
    action, _states = model.predict(obs, deterministic=True)
    # 执行动作
    obs, reward, terminated, truncated, info = env.step(action)
    # 计算总奖励
    total_reward += reward

    # 如果终止或截断
    if terminated or truncated:
        print(f"reward: {total_reward}")
        print(f"truncated: {truncated}")
        print(f"terminated: {terminated}")
        break
# Out:
# /usr/local/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run A2C on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# reward: -21.0
# truncated: False
# terminated: True

# %%
gym.register_envs(ale_py)




# 创建并行环境并堆叠4帧
vec_env = make_vec_env(
    "ALE/Pong-v5", 
    n_envs=8, 
    
    wrapper_kwargs=dict(num_stack=4)
)

model = A2C(
    "CnnPolicy",
    vec_env,
    learning_rate=3e-4,
    ent_coef=0.01,          # 维持探索性
    verbose=1,
    tensorboard_log="./a2c_pong_logs/"
)

model.learn(total_timesteps=2_000_000)
model.save("a2c_pong_cnn")
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./a2c_pong_logs/A2C_1
# ------------------------------------
# | time/                 |          |
# |    fps                | 729      |
# |    iterations         | 100      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0.0902   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.104    |
# |    value_loss         | 0.0044   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 917      |
# |    ep_rew_mean        | -20.1    |
# | time/                 |          |
# |    fps                | 724      |
# |    iterations         | 200      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 8000     |
# ...

# %%
#导入必要的库
import gymnasium as gym
import ale_py
from stable_baselines3 import A2C
from stable_baselines3.common.env_util import make_vec_env
# Out:
# 2025-05-16 23:54:31.237663: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-16 23:54:31.278614: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-16 23:54:32.066085: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import gymnasium as gym
from stable_baselines3 import PPO

# 创建环境（无需手动注册，但需确保已安装 ale-py）
env = gym.make("ALE/Pong-v5", render_mode="human")

# 加载模型时必须添加 .zip 后缀
model = A2C.load("/mnt/workspace/强化学习-2/a2c/a2c_pong_cnn.zip")  # ✅ 确保模型文件路径正确

obs, info = env.reset()  # 重置环境
total_reward = 0  # 总奖励

# 迭代1000次
for _ in range(1000):
    # 确定性策略
    action, _states = model.predict(obs, deterministic=True)
    # 执行动作
    obs, reward, terminated, truncated, info = env.step(action)
    # 计算总奖励
    total_reward += reward

    # 如果终止或截断
    if terminated or truncated:
        print(f"reward: {total_reward}")
        print(f"truncated: {truncated}")
        print(f"terminated: {terminated}")
        break
# Out:
# A.L.E: Arcade Learning Environment (version 0.11.0+dfae0bd)
# [Powered by Stella]

# %%
import gymnasium as gym
from stable_baselines3 import PPO

# 创建环境（无需手动注册，但需确保已安装 ale-py）
env = gym.make("ALE/Pong-v5", render_mode="human")

# 加载模型时必须添加 .zip 后缀
model = A2C.load("/mnt/workspace/强化学习-2/a2c/a2c_pong_cnn.zip")  # ✅ 确保模型文件路径正确

obs, info = env.reset()  # 重置环境
total_reward = 0  # 总奖励

# 迭代1000次
for _ in range(1000):
    # 确定性策略
    action, _states = model.predict(obs, deterministic=True)
    # 执行动作
    obs, reward, terminated, truncated, info = env.step(action)
    # 计算总奖励
    total_reward += reward

    # 如果终止或截断
    if terminated or truncated:
        print(f"reward: {total_reward}")
        print(f"truncated: {truncated}")
        print(f"terminated: {terminated}")
        break
# Out:
# A.L.E: Arcade Learning Environment (version 0.11.0+dfae0bd)
# [Powered by Stella]

# %%
import gymnasium as gym
from stable_baselines3 import A2C

# 创建环境（无需手动注册，但需确保已安装 ale-py）
env = gym.make("ALE/Pong-v5", render_mode="human")

# 加载模型时必须添加 .zip 后缀
model = A2C.load("/mnt/workspace/强化学习-2/a2c/a2c_pong_cnn.zip")  # ✅ 确保模型文件路径正确
# Out:
# A.L.E: Arcade Learning Environment (version 0.11.0+dfae0bd)
# [Powered by Stella]

# %%
obs, info = env.reset()  # 重置环境
total_reward = 0  # 总奖励

# 迭代1000次
for _ in range(1000):
    # 确定性策略
    action, _states = model.predict(obs, deterministic=True)
    # 执行动作
    obs, reward, terminated, truncated, info = env.step(action)
    # 计算总奖励
    total_reward += reward

    # 如果终止或截断
    if terminated or truncated:
        print(f"reward: {total_reward}")
        print(f"truncated: {truncated}")
        print(f"terminated: {terminated}")
        break
